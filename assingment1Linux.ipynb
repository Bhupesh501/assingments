# %% [markdown]
# #assignment name- Linux assignment 1

# %% [markdown]
# 1. **What is Linux?**<br>
# Linux is operating system.this operating sstem we can run on low end device.no need of high end specifications.

# %% [markdown]
# 2. **What is the difference between Hard Link & Soft Link?**><br>
#    Soft link is like shortcut in Windows but in linux we called them soflink. using softlinks we can open orignal file.size of soft link is smaller than orignal file and when we delete the orignal file than softlinks are useless.and softlink and orignal file have different inode<br>
#    Hardlink is copy of folder with different name.Hardlink have same size as orignal file. when we delete orignal file than also we can access hardlink. hardlink have same inode as orignal folder.

# %% [markdown]
# 3. **What is a Kernel in Linux?**<br>
#   kernel is core component of linux or any other os. its serving essantial interface between hardware and software applications. its like brigde between hardware and software without kernel we can not use software and hard ware

# %% [markdown]
# 4. **How do you create a user account?**<br>
#   we can create new user or add user in linux using adduser command
#
#
# ```
# sudo adduser <user name which is you want to add>
# ```

# %% [markdown]
# 5. **What is the ‘grep’ command used for in Linux?**<br>
#    Grep command is use to search perticuler content, content like text or code in perticuler files.

# %% [markdown]
# 6.**Step1: Create user p1**<br>
#     ![Screenshot from 2025-09-18 11-20-52.png](data:image/png;base64,...)
#
#   &nbsp;**Step2: He should be part of 3 groups g1,g2,g3.**<br>
#   ![Screenshot from 2025-09-18 11-26-11.png](data:image/png;base64,...)
#   <br>
#   ![Screenshot from 2025-09-18 11-35-00.png](data:image/png;base64,...)<br>
#   This commands are used to add p1 user in all this group. and also we set g1 group as primary group of p1.when we add file in user p1 then automatically add that file in g1.
#   <br>
#
# &nbsp; **Step3: whenever he creates a file automatically in the group section of file grp g1 should come.**
#
#
# ![Screenshot from 2025-09-18 12-08-26.png](data:image/png;base64,...)
# ![Screenshot from 2025-09-18 11-51-54.png](data:image/png;base64,...)
# <br>
# In this we can see whenever we create folder or file in user p1 then it will also created in g1

# %% [markdown]
# 7.**Step1: Create directory /tmp/bg as root user and create files inside it.**
#
# ![Screenshot from 2025-09-18 12-39-37.png](data:image/png;base64,...)
#
#
#
#
#
# ![Screenshot from 2025-09-18 12-39-52.png](data:image/png;base64,...)
#
#
#
# ![Screenshot from 2025-09-18 12-43-27.png](data:image/png;base64,...)
#
#
#
# &nbsp; **Step2: “bhu” should be the owner of    the  directory. He should be able to create  files and delete files inside the directory and also he should be able to add content to all files**
#
# ![Screenshot from 2025-09-18 12-53-18.png](data:image/png;base64,...)
#
#
# ![Screenshot from 2025-09-18 12-33-28.png](data:image/png;base64,...)
#
# In second screenshot we change the permissions of read write exicute permission it gives only to the owner

# %% [markdown]
# 8.**You suspect that a particular process is consuming excessive CPU resources on your Linux server. How would you identify and terminate this process?**
#
#  first i find which process consume cpu using top command and than note down their pid(process id)
#  and then I will terminate that process using kill command
#
#
# ```
# top
# kill <pid>
# ```
# above commands I will use to troubleshoot problem
